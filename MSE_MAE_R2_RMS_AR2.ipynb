# %%
# diff MSE, MSE, RSME, R2_score, adjacent R2 score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
df=pd.read_csv('placement-2.csv')
df.head()
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1
# 2  7.54                  40.0       1
# 3  6.42                   8.0       1
# 4  7.23                  17.0       0

# %%
df.isna().sum()
# Out:
# cgpa                    0
# placement_exam_marks    0
# placed                  0
# dtype: int64

# %%
df.shape
# Out:
# (1000, 3)

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,2:3]

# %%
plt.figure(figsize=(6,4))
plt.scatter(df['cgpa'],df['placement_exam_marks'])

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,random_state=0,test_size=.3)
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((700, 2), (300, 2), (700, 1), (300, 1))

# %%
lr=LinearRegression()
lr.fit(X_train,Y_train)
y_predict=lr.predict(X_test)

# %%
# mean_absolute_error
mean_absolute_error(y_predict,Y_test)
# Out:
# 0.49957337235222354

# %%
#mean_squared_error
mean_squared_error(y_predict,Y_test)
# Out:
# 0.2500104934197317

# %%
# root mean_squared_error
np.sqrt(mean_squared_error(y_predict,Y_test))
# Out:
# np.float64(0.5000104933096221)

# %%
# r2_score
r2=r2_score(y_predict,Y_test)
r2
# Out:
# -987.6898390569949

# %%
X_test.shape
# Out:
# (300, 2)

# %%
# adjacent r2_score
1-((1-r2)*(300-1))/(300-1-1)
# Out:
# -991.0075901947699
